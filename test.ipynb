# %%
import nnfs 
import pandas as pd 
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import nnfs
#       2 import pandas as pd
#       3 from sklearn.preprocessing import StandardScaler
#
# File ~/Documents/github repos/neural-network-from-scratch-using-numpy-/nnfs.py:2
#       1 #from multipledispatch import dispatch
# ----> 2 import numpy as np
#       4 # declaring and initiating a dictionary, that will contain all the required activation functions and its derivattive
#       5 activation_functions = {
#       6        'relu' : {
#       7            'foreward' : lambda z: np.maximum(0, z),
#    (...)
#      18        }
#      19    }
#
# ModuleNotFoundError: No module named 'numpy'

# %%
data = pd.read_csv("df_train.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv("df_train.csv")
#
# NameError: name 'pd' is not defined
